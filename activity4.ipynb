# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('accident_data.csv')

# %%
df.describe(include ='all')
# Out:
#            Index Accident_Severity Accident Date       Latitude  \
# count     660679            660679        660679  660654.000000
# unique    421020                 3          1461            NaN
# top     2.01E+12            Slight    30-11-2019            NaN
# freq      239478            563801           704            NaN
# mean         NaN               NaN           NaN      52.553866
# std          NaN               NaN           NaN       1.406922
# min          NaN               NaN           NaN      49.914430
# 25%          NaN               NaN           NaN      51.490690
# 50%          NaN               NaN           NaN      52.315641
# 75%          NaN               NaN           NaN      53.453452
# max          NaN               NaN           NaN      60.757544
#
#        Light_Conditions District Area      Longitude  Number_of_Casualties  \
# count            660679        660679  660653.000000         660679.000000
# ...

# %%
df
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
df.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
df['Latitude'] = df['Latitude'].fillna(df['Latitude'].mode()[0])
df['Longitude'] = df['Longitude'].fillna(df['Longitude'].mode()[0])
df['Road_Surface_Conditions'] = df['Road_Surface_Conditions'].fillna(df['Road_Surface_Conditions'].mode()[0])
df['Road_Type'] = df['Road_Type'].fillna(df['Road_Type'].mode()[0])
df['Urban_or_Rural_Area'] = df['Urban_or_Rural_Area'].fillna(df['Urban_or_Rural_Area'].mode()[0])
df['Weather_Conditions'] = df['Weather_Conditions'].fillna(df['Weather_Conditions'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %%
df.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
df['Accident_Severity'] = df['Accident_Severity'].astype('category')
df['Accident Date'] = pd.to_datetime(df['Accident Date'],dayfirst =True, errors='coerce')
df['Light_Conditions'] = df['Light_Conditions'].astype('category')
df['District Area'] = df['District Area'].astype('category')
df['Road_Surface_Conditions'] = df['Road_Surface_Conditions'].astype('category')
df['Road_Type'] = df['Road_Type'].astype('category')
df['Urban_or_Rural_Area'] = df['Urban_or_Rural_Area'].astype('category')
df['Weather_Conditions'] = df['Weather_Conditions'].astype('category')
df['Vehicle_Type'] = df['Vehicle_Type'].astype('category')

# %%
df.dtypes
# Out:
# Index                              object
# Accident_Severity                category
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                 category
# District Area                    category
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions          category
# Road_Type                        category
# Urban_or_Rural_Area              category
# Weather_Conditions               category
# Vehicle_Type                     category
# dtype: object

# %%
df['Year'] = df['Accident Date'].dt.year
df['Month'] = df['Accident Date'].dt.month
df['Day'] = df['Accident Date'].dt.day
df['DayOfWeek'] = df['Accident Date'].dt.dayofweek
df.isnull().sum()
# Out:
# Index                           0
# Accident_Severity               0
# Accident Date              395672
# Latitude                        0
# Light_Conditions                0
# District Area                   0
# Longitude                       0
# Number_of_Casualties            0
# Number_of_Vehicles              0
# Road_Surface_Conditions         0
# Road_Type                       0
# Urban_or_Rural_Area             0
# Weather_Conditions              0
# Vehicle_Type                    0
# Year                       395672
# Month                      395672
# Day                        395672
# DayOfWeek                  395672
# dtype: int64

# %%
df.count()
# Out:
# Index                      660679
# Accident_Severity          660679
# Accident Date              265007
# Latitude                   660679
# Light_Conditions           660679
# District Area              660679
# Longitude                  660679
# Number_of_Casualties       660679
# Number_of_Vehicles         660679
# Road_Surface_Conditions    660679
# Road_Type                  660679
# Urban_or_Rural_Area        660679
# Weather_Conditions         660679
# Vehicle_Type               660679
# Year                       265007
# Month                      265007
# Day                        265007
# DayOfWeek                  265007
# dtype: int64

# %%
df
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    2019-06-05  51.506187
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 2       200701BS66127           Serious           NaT  51.517715
# 3       200701BS66128           Serious           NaT  51.495478
# 4       200701BS66837            Slight    2019-09-03  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight           NaT  57.374005
# 660675  201091NM01881            Slight           NaT  57.232273
# 660676  201091NM01935            Slight           NaT  57.585044
# 660677  201091NM01964           Serious           NaT  57.214898
# 660678  201091NM02142           Serious           NaT  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# <h1>accident happened in 2019</h1>

# %%
df_2019= df[df['Year'] == 2019]

# %%
df_2019['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       52518
# Darkness - lights lit          14124
# Darkness - no lighting          4242
# Darkness - lighting unknown      719
# Darkness - lights unlit          264
# Name: count, dtype: int64

# %% [markdown]
# <h1> Question1: Most accident severity happend in 2019</h1>
# <h3>the most accident severity happend in 2019 are Slight have 84% severity and the ser</h3>

# %%
df_2019['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     60928
# Serious     9823
# Fatal       1116
# Name: count, dtype: int64

# %%
df_2019['Accident_Severity'].value_counts().sum()
# Out:
# np.int64(71867)

# %% [markdown]
# <h1> Question2: Does a slight accident often happen during daylight?</h1>

# %%
accident = df_2019[(df_2019['Light_Conditions']=='Daylight')&(df_2019['Accident_Severity']=='Slight')]

# %% [markdown]
# <h1> Question3: How do road type single carriageway, weather conditions of have a no winds , and the number of car vehicles involved influence the occurrence of slight accidents during daylight??</h1>

# %%
accident.count().sum()
# Out:
# np.int64(813798)

# %%
accident = df_2019[(df_2019['Road_Type']=='Single carriageway')&(df_2019['Weather_Conditions']=='Fine no high winds')& (df_2019['Vehicle_Type']=='Car')]

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    2019-06-05  51.506187
# 7       200701BS67370             Fatal    2019-10-03  51.482260
# 17      200701BS68160           Serious    2019-10-10  51.508445
# 30      200701BS70009            Slight    2019-01-09  51.514489
# 32      200701BS70011            Slight    2019-01-02  51.494902
# ...               ...               ...           ...        ...
# 182080       2.01E+12            Slight    2019-10-08  55.119121
# 182081       2.01E+12            Slight    2019-10-09  54.995479
# 182101       2.01E+12            Slight    2019-12-02  55.009139
# 182102       2.01E+12            Slight    2019-12-03  54.993061
# 182104       2.01E+12            Slight    2019-12-07  54.988202
#
#               Light_Conditions           District Area  Longitude  \
# 0        Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
accident.value_counts().sum()
# Out:
# np.int64(32312)

# %% [markdown]
# <h1> Question4: the total of vehicles  are accident in year 2020  </h1>
# <h3>the total of vehicles was accident in year 2020 is  70163 </h3>

# %%
df_2020= df[df['Year'] == 2020]

# %%
df_2020
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 182120  200801BS70001           Serious    2020-01-02  51.491521
# 182121  200801BS70002            Slight    2020-01-06  51.484909
# 182122  200801BS70003           Serious    2020-01-12  51.509965
# 182123  200801BS70004            Slight    2020-01-05  51.490631
# 182124  200801BS70005            Slight    2020-01-03  51.509712
# ...               ...               ...           ...        ...
# 352694       2.01E+12            Slight    2020-11-01  55.267100
# 352695       2.01E+12            Slight    2020-11-02  54.985218
# 352696       2.01E+12            Slight    2020-11-06  55.126057
# 352697       2.01E+12           Serious    2020-11-04  55.243971
# 352702       2.01E+12            Slight    2020-12-06  54.983911
#
#               Light_Conditions           District Area  Longitude  \
# 182120   Darkness - lights lit  Kensington and Chelsea  -0.179406
# ...

# %%
df_2020['Number_of_Vehicles'].value_counts()
# Out:
# Number_of_Vehicles
# 2     41363
# 1     21603
# 3      5581
# 4      1221
# 5       237
# 6        91
# 7        45
# 8        13
# 10        4
# 9         3
# 11        1
# 14        1
# Name: count, dtype: int64

# %%
df_2020.value_counts().sum()
# Out:
# np.int64(70163)

# %%
vehicle_counts = df_2020['Number_of_Vehicles'].value_counts().sort_index()


plt.figure(figsize=(10, 5))
sns.barplot(x=vehicle_counts.index, y=vehicle_counts.values, palette="coolwarm")

plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Number of Accidents')
plt.title('Accidents by Number of Vehicles Involved (2020)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\3293836791.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=vehicle_counts.index, y=vehicle_counts.values, palette="coolwarm")

# %% [markdown]
# <h1> Question5: < How many total vehicles are involved in accidents that occur during daylight? </h1>

# %%
accident = df_2020[(df_2020['Light_Conditions']=='Daylight')&(df_2020['Number_of_Vehicles'])]

# %%
accident.value_counts().sum()
# Out:
# np.int64(18856)

# %% [markdown]
# <h1> Question6: Which year had the highest number of vehicles involved in accidents that occurred light conditions? </h1>
# <h3> The highest  vehicles involve in accident occured light coindition is year 2019</h3>

# %%
df = df.groupby(['Year','Number_of_Vehicles','Light_Conditions']).size()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\3771688746.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = df.groupby(['Year','Number_of_Vehicles','Light_Conditions']).size()

# %%
df.unstack()
# Out:
# Light_Conditions           Darkness - lighting unknown  Darkness - lights lit  \
# Year   Number_of_Vehicles
# 2019.0 1                                           246                   4865
#        2                                           417                   7963
#        3                                            47                    989
#        4                                             8                    226
#        5                                             1                     52
# ...                                                ...                    ...
# 2022.0 15                                            0                      0
#        16                                            0                      0
#        19                                            0                      0
#        28                                            0                      0
#        32                                            0                      0
#
# ...

# %% [markdown]
# <h1> Question7 What are the most common road surface conditions for accidents in the year 2020</h1>
# <h3>The most common road surface condition for accidents in the year 2020 was dry, accounting for 62.38% of all accidents, compared to wet, frost, snow, and flood conditions.</h3>

# %%
df_2020['Road_Surface_Conditions'].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     43767
# Wet or damp             23539
# Frost or ice             2309
# Snow                      370
# Flood over 3cm. deep      178
# Name: count, dtype: int64

# %%
df_2020['Road_Surface_Conditions'].value_counts().sum()
# Out:
# np.int64(70163)

# %% [markdown]
# <h1> Question8 What month have a common serious accident </h1>

# %%
accident = df_2020[(df_2020['Accident_Severity']=='Serious')&(df_2020['Month'])]

# %%
accident.count()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# Year                       0
# Month                      0
# Day                        0
# DayOfWeek                  0
# dtype: int64

# %% [markdown]
# <h1> Question8 what are common accident in urban in year 2020  </h1>

# %%
df = df_2020.groupby(['Accident_Severity','Urban_or_Rural_Area','Year']).size()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\4018442517.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = df_2020.groupby(['Accident_Severity','Urban_or_Rural_Area','Year']).size()

# %%
df.unstack()
# Out:
# Year                                   2020.0
# Accident_Severity Urban_or_Rural_Area
# Fatal             Rural                   607
#                   Unallocated               0
#                   Urban                   335
# Serious           Rural                  3964
#                   Unallocated               0
#                   Urban                  5382
# Slight            Rural                 21108
#                   Unallocated               2
#                   Urban                 38765

# %% [markdown]
# <h1> Question9 What is the most frequent accident severity type in 2020?   </h1>

# %%
df_2020
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 182120  200801BS70001           Serious    2020-01-02  51.491521
# 182121  200801BS70002            Slight    2020-01-06  51.484909
# 182122  200801BS70003           Serious    2020-01-12  51.509965
# 182123  200801BS70004            Slight    2020-01-05  51.490631
# 182124  200801BS70005            Slight    2020-01-03  51.509712
# ...               ...               ...           ...        ...
# 352694       2.01E+12            Slight    2020-11-01  55.267100
# 352695       2.01E+12            Slight    2020-11-02  54.985218
# 352696       2.01E+12            Slight    2020-11-06  55.126057
# 352697       2.01E+12           Serious    2020-11-04  55.243971
# 352702       2.01E+12            Slight    2020-12-06  54.983911
#
#               Light_Conditions           District Area  Longitude  \
# 182120   Darkness - lights lit  Kensington and Chelsea  -0.179406
# ...

# %%
df_2020['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     59875
# Serious     9346
# Fatal        942
# Name: count, dtype: int64

# %% [markdown]
# <h1> Question10 WWhat is the relationship between light conditions slight and accident severity?  </h1>

# %%
accident = df_2020[(df_2020['Accident_Severity']=='Daylight')&(df_2020['Light_Conditions']=='daylight')]
accident.value_counts().sum()
# Out:
# np.int64(0)

# %%
accident_daylight = df_2020[df_2020['Light_Conditions'] == 'Daylight']

# Counting occurrences by severity
severity_counts = accident_daylight['Accident_Severity'].value_counts()

# Plotting a bar chart
plt.figure(figsize=(8, 5))
sns.barplot(x=severity_counts.index, y=severity_counts.values, palette="coolwarm")
plt.xlabel('Accident Severity')
plt.ylabel('Count of Accidents')
plt.title('Accidents Under Daylight Conditions by Severity')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\2366049951.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=severity_counts.index, y=severity_counts.values, palette="coolwarm")

# %% [markdown]
# <h1> Questiont11 How does accident severity change based on district area, road type, and weather conditions?  </h1>

# %%
df = df_2020.groupby(['District Area','Road_Type','Weather_Conditions']).size()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\2290502769.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = df_2020.groupby(['District Area','Road_Type','Weather_Conditions']).size()

# %%
df.unstack()
# Out:
# Weather_Conditions                Fine + high winds  Fine no high winds  \
# District Area Road_Type
# Aberdeen City Dual carriageway                    2                  35
#               One way street                      0                   4
#               Roundabout                          0                  12
#               Single carriageway                  3                 104
#               Slip road                           0                   1
# ...                                             ...                 ...
# York          Dual carriageway                    0                  14
#               One way street                      0                   8
#               Roundabout                          0                   8
#               Single carriageway                  2                 111
#               Slip road                           0                   0
#
# Weather_Conditions                Fog or mist  Other  Raining + high winds  \
# ...

# %% [markdown]
# <h1> Question12Which district had the highest number of reported accidents?  </h1>

# %%
df_2020['District Area'].value_counts()
# Out:
# District Area
# Birmingham                   1438
# Leeds                         921
# Manchester                    721
# Glasgow City                  676
# Sheffield                     600
#                              ...
# Cheshire West and Chester       0
# County Durham                   0
# Cornwall                        0
# Cheshire East                   0
# Central Bedfordshire            0
# Name: count, Length: 422, dtype: int64

# %%
district_counts = df_2020['District Area'].value_counts()


plt.figure(figsize=(10, 6))
sns.histplot(district_counts, bins=20, kde=True, color='blue')
plt.xlabel('Number of Accidents')
plt.ylabel('Number of Districts')
plt.title('Distribution of Accidents Across Districts')
plt.grid(True)
plt.show()

# %% [markdown]
# <h1> Question13 Is there a correlation between the number of vehicles involved and Number_of_Casualties	 </h1>
# <h3>There have correlation between vehicles and casualties</h3>

# %%
df = df_2020['Number_of_Vehicles'].corr(df_2020['Number_of_Casualties'])

# %%
df.unstack()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.unstack()
#
# AttributeError: 'numpy.float64' object has no attribute 'unstack'

# %% [markdown]
# <h1> Question14 Which combination of road type, light conditions, and accident severity has the highest number of casualties? </h1>

# %%
df = df_2020.groupby(['Road_Type','Light_Conditions','Number_of_Casualties']).size()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\1911437992.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = df_2020.groupby(['Road_Type','Light_Conditions','Number_of_Casualties']).size()

# %%
df.unstack()
# Out:
# Number_of_Casualties                               1     2     3    4    5   \
# Road_Type          Light_Conditions
# Dual carriageway   Darkness - lighting unknown     64    19     3    2    0
#                    Darkness - lights lit         1461   424   133   43   18
#                    Darkness - lights unlit         45     5     1    1    0
#                    Darkness - no lighting         565   177    64   27   14
#                    Daylight                      5323  1411   456  142   58
# One way street     Darkness - lighting unknown      8     3     0    0    0
#                    Darkness - lights lit          286    34    12    5    0
#                    Darkness - lights unlit          5     0     0    0    0
#                    Darkness - no lighting           8     5     1    0    0
#                    Daylight                       922   108    23    4    4
# Roundabout         Darkness - lighting unknown     48     6     1    1    0
# ...

# %%
ddf_grouped = df_2020.groupby(['Road_Type', 'Light_Conditions'])['Number_of_Casualties'].sum().reset_index()

# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_grouped, x='Road_Type', y='Number_of_Casualties', hue='Light_Conditions', marker='o', linewidth=2.5)

plt.xlabel('Road Type')
plt.ylabel('Total Number of Casualties')
plt.title('Casualties by Road Type and Light Conditions')
plt.legend(title='Light Conditions')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\4277132263.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ddf_grouped = df_2020.groupby(['Road_Type', 'Light_Conditions'])['Number_of_Casualties'].sum().reset_index()

# %% [markdown]
# <h1>Question15 What is the total number of vehicles involved in accidents in 2020 </h1>

# %%
df_2020['Number_of_Casualties'].value_counts()
# Out:
# Number_of_Casualties
# 1     53696
# 2     11442
# 3      3285
# 4      1061
# 5       403
# 6       156
# 7        68
# 8        20
# 9        14
# 10        4
# 11        3
# 15        3
# 19        2
# 12        2
# 27        1
# 21        1
# 17        1
# 13        1
# Name: count, dtype: int64

# %%
casualty_counts = df_2020['Number_of_Casualties'].value_counts().sort_index()

# Plotting a bar chart
plt.figure(figsize=(8, 5))
sns.barplot(x=casualty_counts.index, y=casualty_counts.values, palette="coolwarm")
plt.xlabel('Number of Casualties')
plt.ylabel('Count of Accidents')
plt.title('Distribution of Number of Casualties in Accidents')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\3700926296.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=casualty_counts.index, y=casualty_counts.values, palette="coolwarm")

# %% [markdown]
# <h1> Question16 How does the number of casualties relate Month? </h1>
# <h3>There have a relationship the between casualties and month</h3>

# %%
df = df_2020['Number_of_Vehicles'].corr(df_2020['Month'])

# %%
df
# Out:
# np.float64(-0.007071974060197183)

# %%
correlation = df_2020['Number_of_Vehicles'].corr(df_2020['Month'])


plt.figure(figsize=(8, 5))
sns.regplot(x='Month', y='Number_of_Vehicles', data=df_2020, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.xlabel('Month')
plt.ylabel('Number of Vehicles Involved')
plt.title(f'Scatter Plot of Number of Vehicles vs. Month (Correlation: {correlation:.2f})')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %% [markdown]
# <h1>Question 17 How does the time of the accident (day/night), road surface condition, and number of casualties affect the severity? </h1>

# %%
df = df_2020.groupby(['Light_Conditions','Road_Surface_Conditions','Accident_Severity']).size()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\1028734352.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = df_2020.groupby(['Light_Conditions','Road_Surface_Conditions','Accident_Severity']).size()

# %%
df
# Out:
# Light_Conditions             Road_Surface_Conditions  Accident_Severity
# Darkness - lighting unknown  Dry                      Fatal                    4
#                                                       Serious                 45
#                                                       Slight                 399
#                              Flood over 3cm. deep     Fatal                    0
#                                                       Serious                  0
#                                                                            ...
# Daylight                     Snow                     Serious                 24
#                                                       Slight                 212
#                              Wet or damp              Fatal                  154
#                                                       Serious               1668
#                                                       Slight               12801
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_grouped, x='Road_Surface_Conditions', y='Count', hue='Accident_Severity', style='Light_Conditions', s=100, palette='coolwarm')

plt.xlabel('Road Surface Conditions')
plt.ylabel('Number of Accidents')
plt.title('Scatter Plot of Accidents by Road Surface, Light Conditions, and Severity')
plt.xticks(rotation=45, ha='right')
plt.legend(title="Accident Severity", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# df.unstack()

# %%
# Pivoting the grouped data for a stacked bar chart format
df_pivot = df_2020.groupby(['Light_Conditions', 'Road_Surface_Conditions', 'Accident_Severity']).size().unstack()

# Plot stacked bar chart
df_pivot.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='coolwarm')
plt.xlabel('Light & Road Conditions')
plt.ylabel('Number of Accidents')
plt.title('Accidents by Light, Road, and Severity Conditions')
plt.xticks(rotation=45, ha='right')
plt.legend(title="Accident Severity")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\956822065.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_pivot = df_2020.groupby(['Light_Conditions', 'Road_Surface_Conditions', 'Accident_Severity']).size().unstack()

# %% [markdown]
# <h1>Question 18 How many accidents occurred under daylight conditions? </h1>

# %%
df = df_2020['Light_Conditions']=='Daylight'

# %%
df.value_counts()
# Out:
# Light_Conditions
# True     51605
# False    18558
# Name: count, dtype: int64

# %%
daylight_counts = (df_2020['Light_Conditions'] == 'Daylight').value_counts()


plt.figure(figsize=(6, 6))
daylight_counts.plot(kind='pie', autopct='%1.1f%%', labels=['Daylight', 'Non-Daylight'], colors=['lightblue', 'gray'])
plt.title('Proportion of Accidents in Daylight vs. Non-Daylight Conditions')
plt.ylabel('')  
plt.show()

# %% [markdown]
# <h1>Question 19 How does accident severity vary with different road surface conditions? </h1>

# %%
df = df_2020.groupby(['Accident_Severity','Road_Surface_Conditions']).size()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\87316103.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = df_2020.groupby(['Accident_Severity','Road_Surface_Conditions']).size()

# %%
df.unstack()
# Out:
# Road_Surface_Conditions    Dry  Flood over 3cm. deep  Frost or ice  Snow  \
# Accident_Severity
# Fatal                      567                     6            25     2
# Serious                   5954                    23           278    41
# Slight                   37246                   149          2006   327
#
# Road_Surface_Conditions  Wet or damp
# Accident_Severity
# Fatal                            342
# Serious                         3050
# Slight                         20147

# %%
df_grouped = df_2020.groupby(['Road_Surface_Conditions', 'Weather_Conditions', 'Light_Conditions']).size().unstack()


plt.figure(figsize=(10, 6))
sns.heatmap(df_grouped, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Incident Distribution by Road, Weather, and Light Conditions')
plt.xlabel('Weather & Light Conditions')
plt.ylabel('Road Surface Conditions')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\531686794.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_2020.groupby(['Road_Surface_Conditions', 'Weather_Conditions', 'Light_Conditions']).size().unstack()

# %% [markdown]
# <h1>Question 20 What factors (road surface, weather, and lighting conditions) contribute to serious accident </h1>

# %%
df = df_2020.groupby(['Road_Surface_Conditions','Weather_Conditions','Light_Conditions']).size()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\869934574.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = df_2020.groupby(['Road_Surface_Conditions','Weather_Conditions','Light_Conditions']).size()

# %%
df.unstack()
# Out:
# Light_Conditions                               Darkness - lighting unknown  \
# Road_Surface_Conditions Weather_Conditions
# Dry                     Fine + high winds                                1
#                         Fine no high winds                             444
#                         Fog or mist                                      0
#                         Other                                            2
#                         Raining + high winds                             0
#                         Raining no high winds                            1
#                         Snowing + high winds                             0
#                         Snowing no high winds                            0
# Flood over 3cm. deep    Fine + high winds                                0
#                         Fine no high winds                               0
#                         Fog or mist                                      0
# ...

# %%
df_grouped = df_2020.groupby(['Road_Surface_Conditions', 'Weather_Conditions', 'Light_Conditions']).size().unstack()


plt.figure(figsize=(10, 6))
sns.heatmap(df_grouped, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Incident Distribution by Road, Weather, and Light Conditions')
plt.xlabel('Weather & Light Conditions')
plt.ylabel('Road Surface Conditions')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4568\531686794.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_2020.groupby(['Road_Surface_Conditions', 'Weather_Conditions', 'Light_Conditions']).size().unstack()
